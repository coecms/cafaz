# %%
import cafaz
import climtas.nci

# %%
c = climtas.nci.Client()
c
# Out:
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-guvalk3l', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-4oglhtyn', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-p9yfbonp', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-06050iff', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-a7a7h2u3', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-a1tevsjn', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/local/w35/ccc561/tmp/dask-worker-space/worker-6_3cljoo', purging
# ...

# %%
var_to_process = [
    ("precip",  "atmos_hybrid", "month"),
    ("sst", "ocean", "month"),
    ("evap", "atmos_hybrid", "month"),
    ("t_surf", "atmos_hybrid", "month"),
    ("slp", "atmos_hybrid", "month"),
    ("hght", "atmos_isobaric", "daily"),
    ("temp", "atmos_isobaric", "daily"),
    ("ucomp", "atmos_isobaric", "daily"),
    ("vcomp", "atmos_isobaric", "daily"),
    ("hght", "atmos_hybrid", "month"),
    ("temp", "atmos_hybrid", "month"),
    ("ucomp", "atmos_hybrid", "month"),
    ("vcomp", "atmos_hybrid", "month"),
    ("temp", "ocean", "month"),
]

# %%
for var in var_to_process:
    print("Processing var", var[0])
    caf_var = cafaz.Cafaz(*var, json_root="/g/data/w97/ccc561/CAFE60/json")
    caf_var.write_json()
# Out:
# Processing var hght
# Processing var temp
# Processing var ucomp
# Processing var vcomp
# Processing var hght
# Processing var temp
# Processing var ucomp
# Processing var vcomp
# Processing var temp
